# %%
#Porta dos desesperados
#Leila Hikari Hashimoto 178297
#Mariana Yuli Sato Do Nascimento 221914
#Marina de Menezes Lima 221455

# %%
# %matplotlib inline


import matplotlib.pyplot as plt
import random

vezes = 1000

a = 1
b = 2
c= 3
vitorias = 0
perdas = 0
trocou = 0
continuou = 0
ganhoutroca = 0
perdeutroca = 0
ganhoucontinua = 0
perdeucontinua = 0
lista = ['A', 'B', 'C']
x = random.choice(lista)
#print(x)

for m in range(vezes):
        if x == 'A':
            for i in range(1):
                n = random.randint(2,3)
            if n == 2:
                for p in range(1):
                    g = random.randrange(1, 4, 2)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

            else:
                #print('A porta C foi aberta e não há nenhum premio nela. Deseja continuar com a porta A ou trocar para a B?')
                for p in range(1):
                    g = random.randrange(1,2)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

        if x == 'B':
            for i in range(1):
                n = random.randint(2,3)
            if n == 2:
                #print('A porta A foi aberta e não há nenhum premio nela. Deseja continuar com a porta B ou trocar para a C?')
                for p in range(1):
                    g = random.randrange(2,3)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

            else:
                #print('A porta C foi aberta e não há nenhum premio nela. Deseja continuar com a porta B ou trocar para a A?')
                for p in range(1):
                    g = random.randrange(1,2)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

        if x == 'C':
            for i in range(1):
                n = random.randint(2,3)
            if n == 2:
                #print('A porta B foi aberta e não há nenhum premio nela. Deseja continuar com a porta C ou trocar para a A?')
                for p in range(1):
                    g = random.randrange(1, 4, 2)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

            else:
                #print('A porta A foi aberta e não há nenhum premio nela. Deseja continuar com a porta B ou trocar para a C?')
                for p in range(1):
                    g = random.randrange(1, 4, 2)
                lista2 = ['Continuar', 'Trocar']
                resp = random.choice(lista2)
                #print(resp)
                if resp == 'Continuar':
                    continuou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoucontinua += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeucontinua += 1
                else:
                    trocou += 1
                    if a == g:
                        #print('Você ganhou! \n')
                        vitorias += 1
                        ganhoutroca += 1
                    else:
                        #print ('Você perdeu! \n')
                        perdas += 1
                        perdeutroca += 1

print('Total de vitórias:', vitorias)
print('Total de perdas:', perdas)
print('Continuou e ganhou:', ganhoucontinua)
print('Continuou e perdeu:', perdeucontinua)
print('Trocou e ganhou:', ganhoutroca)
print('Trocou e perder:', perdeutroca)

nomes = ['continuou e ganhou', 'continuou e perdeu', 'trocou e ganhou', 'trocou e perdeu']
val = [ganhoucontinua,perdeucontinua,ganhoutroca,perdeutroca]
plt.figure(1, figsize=(9, 3))
grafico = plt.bar(nomes, val)
grafico[0].set_color('#00008B')
grafico[1].set_color('#FF69B4')
grafico[2].set_color('#B22222')
grafico[3].set_color('#00FF7F')
plt.show()
# Out:
# Total de vitórias: 518
# Total de perdas: 482
# Continuou e ganhou: 253
# Continuou e perdeu: 254
# Trocou e ganhou: 265
# Trocou e perder: 228
